# %% [markdown]
# # Test PDPbox with multiclass classification problem
# ## Kaggle Otto Group with RandomForest
# This demo is based on **Otto Group Product Classification Challenge**
# https://www.kaggle.com/c/otto-group-product-classification-challenge

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox import pdp, get_dataset

# %% [markdown]
# ## get dataset

# %%
test_otto = get_dataset.otto()
test_otto.keys()
# Out:
# ['data', 'features', 'rf_model', 'target']

# %%
otto_data = test_otto['data']
otto_features = test_otto['features']
otto_model = test_otto['rf_model']
otto_target = test_otto['target']

# %% [markdown]
# ## test pdp isolate

# %%
# %%time 
pdp_feat_67_rf = pdp.pdp_isolate(model=otto_model, 
                                 dataset=otto_data,
                                 model_features=otto_features,
                                 feature='feat_67')
# Out:
# Wall time: 8.52 s

# %%
fig, axes = pdp.pdp_plot(pdp_isolate_out=pdp_feat_67_rf, 
                         feature_name='feat_67', 
                         center=True, 
                         x_quantile=True, 
                         ncols=3, 
                         plot_lines=True, 
                         frac_to_plot=100)

# %%
fig, axes = pdp.pdp_plot(pdp_feat_67_rf, 'feat_67', center=True, x_quantile=True, ncols=2, 
                         plot_lines=True, frac_to_plot=100, which_classes=[0, 3, 7])

# %%
fig, axes = pdp.pdp_plot(pdp_feat_67_rf, 'feat_67', center=True, x_quantile=True, ncols=2, 
                         plot_lines=True, frac_to_plot=100, which_classes=[0, 3, 7], plot_pts_dist=True)

# %% [markdown]
# ### interaction between feat_67 and feat_24

# %%
# %%time
pdp_67_24_rf = pdp.pdp_interact(model=otto_model, 
                                dataset=otto_data, 
                                model_features=otto_features, 
                                features=['feat_67', 'feat_24'], 
                                num_grid_points=[10, 10],  percentile_ranges=[None, None], n_jobs=4)
# Out:
# CPU times: user 25.2 s, sys: 5.82 s, total: 31.1 s
# Wall time: 35.7 s

# %%
fig, axes = pdp.pdp_interact_plot(pdp_67_24_rf, ['feat_67', 'feat_24'], plot_type='grid',
                                  x_quantile=True, ncols=2, plot_pdp=True, which_classes=[1, 2, 3])

# %%
axes
# Out:
# {'pdp_inter_ax': [{'pdp_inter_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cafdb850>,
#    'pdp_x_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27caf9c050>,
#    'pdp_y_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cafb9bd0>},
#   {'pdp_inter_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cae23b50>,
#    'pdp_x_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cadeec90>,
#    'pdp_y_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cad8e890>},
#   {'pdp_inter_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cac66ed0>,
#    'pdp_x_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cabc6150>,
#    'pdp_y_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27cab88990>}],
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f27a73fb090>}

# %%
fig, axes = pdp.pdp_interact_plot(pdp_interact_out=pdp_67_24_rf, 
                                  feature_names=['feat_67', 'feat_24'], 
                                  plot_type='grid',
                                  x_quantile=True, 
                                  ncols=2, 
                                  plot_pdp=False, 
                                  which_classes=[1, 2, 3])

# %%
fig, axes = pdp.pdp_interact_plot(pdp_67_24_rf, ['feat_67', 'feat_24'], plot_type='contour',
                                  x_quantile=True, ncols=2, plot_pdp=True, which_classes=[1, 2, 3], 
                                  figsize=(15, 18))

# %%
fig, axes = pdp.pdp_interact_plot(pdp_67_24_rf, ['feat_67', 'feat_24'], plot_type='contour',
                                  x_quantile=True, ncols=2, plot_pdp=False, which_classes=[1, 2, 3])

# %%
fig, axes = pdp.pdp_interact_plot(pdp_67_24_rf, ['feat_67', 'feat_24'], plot_type='contour',
                                  x_quantile=True, ncols=2, plot_pdp=False, which_classes=[3])
