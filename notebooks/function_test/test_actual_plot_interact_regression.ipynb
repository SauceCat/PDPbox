# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test regressor

# %%
test_ross = joblib.load('../../pdpbox/datasets/test_ross.pkl')

ross_data = test_ross['data']
ross_features = test_ross['features']
ross_target = test_ross['target']
ross_model = test_ross['rf_model']

# %% [markdown]
# ## test actual_plot_interact

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot_interact

# %%
fig, axes, df = actual_plot_interact(model=ross_model, 
                                X=ross_data[ross_features], 
                                features=[['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], 'SchoolHoliday'], 
                                feature_names=['StoreType', 'SchoolHoliday'])

# %%
df
# Out:
#    x1  x2 display_column_1 display_column_2   count  actual_prediction_q1  \
# 0   0   0      StoreType_a  SchoolHoliday_0  368267           5757.486750
# 1   0   1      StoreType_a  SchoolHoliday_1   88810           5965.764381
# 2   1   0      StoreType_b  SchoolHoliday_0   12685           8163.116967
# 3   1   1      StoreType_b  SchoolHoliday_1    2878           7853.630698
# 4   2   0      StoreType_c  SchoolHoliday_0   90794           6016.008312
# 5   2   1      StoreType_c  SchoolHoliday_1   22184           5926.961734
# 6   3   0      StoreType_d  SchoolHoliday_0  209189           5816.194259
# 7   3   1      StoreType_d  SchoolHoliday_1   49585           5848.849226
#
#    actual_prediction_q2  actual_prediction_q3
# 0           6622.272652           7647.073243
# 1           7013.743552           8161.607262
# 2           9620.182567          11443.330958
# 3           9405.793364          11456.794087
# 4           6639.155954           7383.338370
# ...

# %%
fig, axes, df = actual_plot_interact(model=ross_model, 
                                X=ross_data[ross_features], 
                                features=[['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], 'weekofyear'], 
                                feature_names=['StoreType', 'weekofyear'], figsize=(15, 15))

# %%
fig, axes, df = actual_plot_interact(model=ross_model, 
                                X=ross_data[ross_features], 
                                features=['weekofyear', 'SchoolHoliday'], 
                                feature_names=['weekofyear', 'SchoolHoliday'], figsize=(15, 8))
