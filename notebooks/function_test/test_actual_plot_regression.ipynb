# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test regressor

# %%
test_ross = joblib.load('../../pdpbox/datasets/test_ross.pkl')

ross_data = test_ross['data']
ross_features = test_ross['features']
ross_target = test_ross['target']
ross_model = test_ross['rf_model']

# %% [markdown]
# ## test actual plot

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot

# %% [markdown]
# #### binary feature

# %%
fig, axes, df = actual_plot(model=ross_model, X=ross_data[ross_features], feature='SchoolHoliday', feature_name='SchoolHoliday')
# Out:
# ../../pdpbox\info_plots.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   info_df['actual_prediction'] = prediction

# %%
df
# Out:
#    x   display_column   count  actual_prediction_q1  actual_prediction_q2  \
# 0  0  SchoolHoliday_0  680935           5828.145813           6622.272652
# 1  1  SchoolHoliday_1  163457           5941.953128           6911.694636
#
#    actual_prediction_q3
# 0           7577.496478
# 1           8157.970575

# %% [markdown]
# #### onehot encoding features

# %%
fig, axes, df = actual_plot(model=ross_model, X=ross_data[ross_features], 
                       feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], feature_name='StoreType')

# %%
df
# Out:
#    x display_column   count  actual_prediction_q1  actual_prediction_q2  \
# 0  0    StoreType_a  457077           5822.815972           6701.824226
# 1  1    StoreType_b   15563           8155.860114           9578.427701
# 2  2    StoreType_c  112978           6007.973935           6653.432827
# 3  3    StoreType_d  258774           5827.154238           6535.522843
#
#    actual_prediction_q3
# 0           7730.564152
# 1          11443.330958
# 2           7470.281513
# 3           7502.296154

# %% [markdown]
# #### numeric feature

# %%
fig, axes, df = actual_plot(model=ross_model, 
                       X=ross_data[ross_features], 
                       feature='weekofyear', 
                       feature_name='weekofyear', 
                       show_percentile='True')

# %%
df
# Out:
#    x  display_column  value_lower  value_upper percentile_column  \
# 0  0    [1.00, 5.00)          1.0          5.0     [0.00, 11.11)
# 1  1   [5.00, 10.00)          5.0         10.0    [11.11, 22.22)
# 2  2  [10.00, 15.00)         10.0         15.0    [22.22, 33.33)
# 3  3  [15.00, 20.00)         15.0         20.0    [33.33, 44.44)
# 4  4  [20.00, 25.00)         20.0         25.0    [44.44, 55.56)
# 5  5  [25.00, 30.00)         25.0         30.0    [55.56, 66.67)
# 6  6  [30.00, 37.00)         30.0         37.0    [66.67, 77.78)
# 7  7  [37.00, 45.00)         37.0         45.0    [77.78, 88.89)
# 8  8  [45.00, 52.00]         45.0         52.0   [88.89, 100.00]
#
#    percentile_lower  percentile_upper   count  actual_prediction_q1  \
# 0          0.000000         11.111111   74699           5828.575845
# 1         11.111111         22.222222  100320           5571.090689
# 2         22.222222         33.333333   97183           5757.486750
# 3         33.333333         44.444444   93010           6130.498788
# 4         44.444444         55.555556   93887           6073.027208
# 5         55.555556         66.666667   96837           5746.654906
# 6         66.666667         77.777778   98408           5721.631257
# 7         77.777778         88.888889   95524           5713.472815
# 8         88.888889        100.000000   94524           6541.190649
#
#    actual_prediction_q2  actual_prediction_q3
# 0           6414.709793           7249.606068
# 1           6349.691503           7150.833879
# 2           6909.805470           7817.497664
# 3           7020.997658           8159.699844
# 4           6599.473723           7455.393664
# 5           6900.042337           7928.553001
# 6           6424.708778           7587.495796
# 7           6471.239785           7180.184889
# 8           7412.577743           9172.505219

# %%
axes
# Out:
# {'bar_ax': <matplotlib.axes._subplots.AxesSubplot at 0x2194f358>,
#  'box_ax': <matplotlib.axes._subplots.AxesSubplot at 0x1f59f390>,
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x21595a90>}
