# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # test regressor

# %%
test_ross = joblib.load('../../pdpbox/datasets/test_ross.pkl')

ross_data = test_ross['data']
ross_features = test_ross['features']
ross_target = test_ross['target']
ross_model = test_ross['rf_model']

# %% [markdown]
# #### (model: regression, feature_type: binary)

# %%
fig, axes, summary_df = target_plot(df=ross_data, 
                               feature='SchoolHoliday', 
                               feature_name='SchoolHoliday', 
                               target='Sales', 
                               figsize=(15, 8))

# %%
summary_df
# Out:
#    x   display_column   count        Sales
# 0  0  SchoolHoliday_0  680935  6896.782411
# 1  1  SchoolHoliday_1  163457  7200.181650

# %% [markdown]
# #### (model: regression, feature_type: onehot)

# %%
fig, axes, summary_df = target_plot(df=ross_data, 
                               feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'],
                               feature_name='StoreType',
                               target='Sales', 
                               figsize=(15, 8))

# %%
summary_df
# Out:
#    x display_column   count         Sales
# 0  0    StoreType_a  457077   6925.167661
# 1  1    StoreType_b   15563  10231.407505
# 2  2    StoreType_c  112978   6932.512755
# 3  3    StoreType_d  258774   6822.141881

# %% [markdown]
# #### (model: multi-class, feature_type: numeric)

# %%
fig, axes, summary_df = target_plot(df=ross_data, 
                               feature='weekofyear', 
                               feature_name='weekofyear', 
                               target='Sales', 
                               figsize=(15, 8))

# %%
summary_df
# Out:
#    x  display_column  value_lower  value_upper   count        Sales
# 0  0    [1.00, 5.00)          1.0          5.0   74699  6611.900307
# 1  1   [5.00, 10.00)          5.0         10.0  100320  6548.074412
# 2  2  [10.00, 15.00)         10.0         15.0   97183  7047.416801
# 3  3  [15.00, 20.00)         15.0         20.0   93010  7150.762251
# 4  4  [20.00, 25.00)         20.0         25.0   93887  6912.765740
# 5  5  [25.00, 30.00)         25.0         30.0   96837  7018.025414
# 6  6  [30.00, 37.00)         30.0         37.0   98408  6713.488893
# 7  7  [37.00, 45.00)         37.0         45.0   95524  6580.778694
# 8  8  [45.00, 52.00]         45.0         52.0   94524  7981.965109

# %%
axes
# Out:
# {'bar_ax': <matplotlib.axes._subplots.AxesSubplot at 0x1fc1a4e0>,
#  'line_ax': <matplotlib.axes._subplots.AxesSubplot at 0x1fc65588>,
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x21f54b38>}

# %%
fig, axes, summary_df = target_plot(df=ross_data, 
                               feature='DayOfWeek', 
                               feature_name='DayOfWeek', 
                               target='Sales', 
                               figsize=(15, 8))

# %%
fig, axes, summary_df = target_plot(df=ross_data, 
                               feature='DayOfWeek', 
                               feature_name='DayOfWeek', 
                               target='Sales', 
                               figsize=(15, 8), 
                               endpoint=False, 
                               cust_grid_points=range(1, 8))
