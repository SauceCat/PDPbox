# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## test binary classifier

# %%
test_titanic = joblib.load('test_titanic.pkl')

titanic_data = test_titanic['data']
titanic_features = test_titanic['features']
titanic_target = test_titanic['target']
titanic_model = test_titanic['xgb_model']

# %% [markdown]
# #### (model: binary, feature_type: binary)

# %%
axes = target_plot(df=titanic_data, feature='Sex', feature_name='Sex', target=titanic_target)

# %%
axes

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
axes[0].plot(range(10), range(10, 20))
ax1 = target_plot(df=titanic_data, feature='Fare', feature_name='fare', target=titanic_target, ax=axes[1])

# %%
ax1

# %%
np.mean(ax1.get_xlim())
# Out:
# 4.0

# %%
ax1.get_xlim()

# %%
a.set_frame_on()

# %% [markdown]
# #### (model: binary, feature_type: one-hot)

# %%
target_plot(df=titanic_data, feature=['Embarked_C', 'Embarked_Q', 'Embarked_S'], 
            feature_name='Embarked', target=titanic_target)

# %% [markdown]
# #### (model: binary, feature_type: numeric)

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target)

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, 
            num_grid_points=20, plot_params={'xticks_rotation': 90})

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, 
            num_grid_points=10, grid_type='percentile', percentile_range=(5, 95))

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, 
            num_grid_points=10, grid_type='equal')

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, 
            num_grid_points=10, grid_type='equal', grid_range=(5, 100))

# %%
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, 
            cust_grid_points=range(0, 100, 10))

# %%
plot_params = {
    'font_family': 'Verdana',
    'title': 'Survival rate for different fares',
    'subtitle': 'Average survival rate through different fare values',
    'title_fontsize': 15,
    'subtitle_fontsize': 10,
    'line_color': 'darkblue',
    'bar_color': 'lightblue',
    'line_width': 1,
    'xticks_rotation': 90
}
target_plot(df=titanic_data, feature='Fare', feature_name='Fare', target=titanic_target, plot_params=plot_params)
