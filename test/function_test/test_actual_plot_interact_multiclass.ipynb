# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test multi-class classifier

# %%
test_otto = joblib.load('test_otto.pkl')

otto_data = test_otto['data']
otto_features = test_otto['features']
otto_target = test_otto['target']
otto_model = test_otto['rf_model']

# %% [markdown]
# ## test actual_plot_interact

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot_interact

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], 
                                which_classes=[1])
# Out:
# ../../pdpbox\info_plots.py:412: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   info_df['actual_prediction_%d' % class_idx] = prediction[:, class_idx]

# %%
df
# Out:
#     x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0    0   0     [0.00, 1.00)     [0.00, 1.00)            0.0            1.0
# 1    0   1     [0.00, 1.00)     [1.00, 3.00)            0.0            1.0
# 2    0   2     [0.00, 1.00)   [3.00, 149.00]            0.0            1.0
# 3    1   0     [1.00, 2.00)     [0.00, 1.00)            1.0            2.0
# 4    1   1     [1.00, 2.00)     [1.00, 3.00)            1.0            2.0
# 5    1   2     [1.00, 2.00)   [3.00, 149.00]            1.0            2.0
# 6    2   0     [2.00, 3.00)     [0.00, 1.00)            2.0            3.0
# 7    2   1     [2.00, 3.00)     [1.00, 3.00)            2.0            3.0
# 8    2   2     [2.00, 3.00)   [3.00, 149.00]            2.0            3.0
# 9    3   0     [3.00, 4.00)     [0.00, 1.00)            3.0            4.0
# 10   3   1     [3.00, 4.00)     [1.00, 3.00)            3.0            4.0
# 11   3   2     [3.00, 4.00)   [3.00, 149.00]            3.0            4.0
# 12   4   0     [4.00, 7.00)     [0.00, 1.00)            4.0            7.0
# 13   4   1     [4.00, 7.00)     [1.00, 3.00)            4.0            7.0
# 14   4   2     [4.00, 7.00)   [3.00, 149.00]            4.0            7.0
# 15   5   0   [7.00, 104.00]     [0.00, 1.00)            7.0          104.0
# 16   5   1   [7.00, 104.00]     [1.00, 3.00)            7.0          104.0
# 17   5   2   [7.00, 104.00]   [3.00, 149.00]            7.0          104.0
#
#     value_lower_2  value_upper_2  count  actual_prediction_1_q1  \
# 0             0.0            1.0  19946                    0.00
# 1             1.0            3.0   3555                    0.00
# 2             3.0          149.0    429                    0.00
# 3             0.0            1.0   7604                    0.00
# 4             1.0            3.0   1903                    0.00
# 5             3.0          149.0    371                    0.00
# 6             0.0            1.0   4987                    0.00
# 7             1.0            3.0   1319                    0.00
# 8             3.0          149.0    383                    0.00
# 9             0.0            1.0   2460                    0.00
# 10            1.0            3.0    987                    0.00
# 11            3.0          149.0    987                    0.01
# 12            0.0            1.0   4258                    0.00
# 13            1.0            3.0   2127                    0.00
# 14            3.0          149.0   2600                    0.01
# 15            0.0            1.0   2707                    0.00
# 16            1.0            3.0   1753                    0.00
# 17            3.0          149.0   3502                    0.00
#
#     actual_prediction_1_q2  actual_prediction_1_q3
# 0                     0.07                   0.720
# 1                     0.00                   0.010
# 2                     0.00                   0.010
# 3                     0.12                   0.920
# 4                     0.00                   0.190
# 5                     0.00                   0.020
# 6                     0.10                   0.920
# 7                     0.00                   0.145
# 8                     0.00                   0.035
# 9                     0.03                   0.920
# 10                    0.00                   0.150
# 11                    0.19                   0.850
# 12                    0.01                   0.820
# 13                    0.00                   0.050
# 14                    0.13                   0.800
# 15                    0.00                   0.030
# 16                    0.00                   0.010
# 17                    0.01                   0.100

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], 
                                which_classes=[1, 2, 3], 
                                figsize=(15, 16))

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], 
                                which_classes=[1, 2, 3], 
                                ncols=1, 
                                figsize=(15, 21))
