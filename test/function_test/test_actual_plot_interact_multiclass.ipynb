# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test multi-class classifier

# %%
test_otto = joblib.load('test_otto.pkl')

otto_data = test_otto['data']
otto_features = test_otto['features']
otto_target = test_otto['target']
otto_model = test_otto['rf_model']

# %% [markdown]
# ## test actual_plot_interact

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot_interact

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], 
                                which_classes=[0, 1, 2, 3, 4], figsize=(15, 24))

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], figsize=(15, 40))

# %%
axes, df = actual_plot_interact(model=otto_model, 
                                X=otto_data[otto_features], 
                                features=['feat_67', 'feat_32'], 
                                feature_names=['feat_67', 'feat_32'], 
                                which_classes=[1, 2], figsize=(15, 8))

# %%
df
# Out:
#     x1  x2 display_column_1 display_column_2  count  actual_prediction_1_q1  \
# 0    0   0     [0.00, 1.00)     [0.00, 1.00)  19946                    0.00
# 1    0   1     [0.00, 1.00)     [1.00, 3.00)   3555                    0.00
# 2    0   2     [0.00, 1.00)   [3.00, 149.00]    429                    0.00
# 3    1   0     [1.00, 2.00)     [0.00, 1.00)   7604                    0.00
# 4    1   1     [1.00, 2.00)     [1.00, 3.00)   1903                    0.00
# 5    1   2     [1.00, 2.00)   [3.00, 149.00]    371                    0.00
# 6    2   0     [2.00, 3.00)     [0.00, 1.00)   4987                    0.00
# 7    2   1     [2.00, 3.00)     [1.00, 3.00)   1319                    0.00
# 8    2   2     [2.00, 3.00)   [3.00, 149.00]    383                    0.00
# 9    3   0     [3.00, 4.00)     [0.00, 1.00)   2460                    0.00
# 10   3   1     [3.00, 4.00)     [1.00, 3.00)    987                    0.00
# 11   3   2     [3.00, 4.00)   [3.00, 149.00]    987                    0.01
# 12   4   0     [4.00, 7.00)     [0.00, 1.00)   4258                    0.00
# 13   4   1     [4.00, 7.00)     [1.00, 3.00)   2127                    0.00
# 14   4   2     [4.00, 7.00)   [3.00, 149.00]   2600                    0.01
# 15   5   0   [7.00, 104.00]     [0.00, 1.00)   2707                    0.00
# 16   5   1   [7.00, 104.00]     [1.00, 3.00)   1753                    0.00
# 17   5   2   [7.00, 104.00]   [3.00, 149.00]   3502                    0.00
#
#     actual_prediction_1_q2  actual_prediction_1_q3  actual_prediction_2_q1  \
# 0                     0.07                   0.720                    0.00
# 1                     0.00                   0.010                    0.00
# 2                     0.00                   0.010                    0.00
# 3                     0.12                   0.920                    0.00
# 4                     0.00                   0.190                    0.00
# 5                     0.00                   0.020                    0.00
# 6                     0.10                   0.920                    0.00
# 7                     0.00                   0.145                    0.00
# 8                     0.00                   0.035                    0.00
# 9                     0.03                   0.920                    0.00
# 10                    0.00                   0.150                    0.00
# 11                    0.19                   0.850                    0.01
# 12                    0.01                   0.820                    0.00
# 13                    0.00                   0.050                    0.00
# 14                    0.13                   0.800                    0.00
# 15                    0.00                   0.030                    0.00
# 16                    0.00                   0.010                    0.00
# 17                    0.01                   0.100                    0.00
#
#     actual_prediction_2_q2  actual_prediction_2_q3
# 0                     0.04                  0.1700
# 1                     0.00                  0.0100
# 2                     0.00                  0.0100
# 3                     0.01                  0.0700
# 4                     0.00                  0.0500
# 5                     0.00                  0.0100
# 6                     0.01                  0.0600
# 7                     0.00                  0.0300
# 8                     0.00                  0.0300
# 9                     0.00                  0.0300
# 10                    0.00                  0.0300
# 11                    0.09                  0.7000
# 12                    0.00                  0.0275
# 13                    0.00                  0.0200
# 14                    0.07                  0.6300
# 15                    0.00                  0.0100
# 16                    0.00                  0.0100
# 17                    0.01                  0.1100
