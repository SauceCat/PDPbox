# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test binary classifier

# %%
test_titanic = joblib.load('../../pdpbox/datasets/test_titanic.pkl')

titanic_data = test_titanic['data']
titanic_features = test_titanic['features']
titanic_target = test_titanic['target']
titanic_model = test_titanic['xgb_model']

# %% [markdown]
# ## test actual_plot_interact

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot_interact

# %% [markdown]
# #### (model: binary, feature_type: binary and onehot)

# %%
fig, axes, df = actual_plot_interact(model=titanic_model, 
                                X=titanic_data[titanic_features], 
                                features=['Sex', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                feature_names=['Sex', 'Embarked'])
# Out:
# ../../pdpbox\info_plots.py:577: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   info_df['actual_prediction'] = prediction[:, 1]

# %%
df
# Out:
#    x1  x2 display_column_1 display_column_2  count  actual_prediction_q1  \
# 0   0   0            Sex_0       Embarked_C     73              0.813235
# 1   0   1            Sex_0       Embarked_Q     36              0.674061
# 2   0   2            Sex_0       Embarked_S    205              0.481871
# 3   1   0            Sex_1       Embarked_C     95              0.158455
# 4   1   1            Sex_1       Embarked_Q     41              0.100760
# 5   1   2            Sex_1       Embarked_S    441              0.099070
#
#    actual_prediction_q2  actual_prediction_q3
# 0              0.931539              0.963071
# 1              0.720176              0.731459
# 2              0.833870              0.914960
# 3              0.244047              0.413279
# 4              0.115931              0.127598
# 5              0.118867              0.174479

# %% [markdown]
# #### (model: binary, feature_type: onehot and numeric)

# %%
fig, axes, df = actual_plot_interact(model=titanic_model, 
                                X=titanic_data[titanic_features],
                                features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                feature_names=['Fare', 'Embarked'], figsize=(15, 8))

# %%
df
# Out:
#     x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0    0   0     [0.00, 7.73)       Embarked_C       0.000000       7.732844
# 1    0   1     [0.00, 7.73)       Embarked_Q       0.000000       7.732844
# 2    0   2     [0.00, 7.73)       Embarked_S       0.000000       7.732844
# 3    1   0     [7.73, 7.90)       Embarked_C       7.732844       7.895800
# 4    1   1     [7.73, 7.90)       Embarked_Q       7.732844       7.895800
# 5    1   2     [7.73, 7.90)       Embarked_S       7.732844       7.895800
# 6    2   0     [7.90, 8.66)       Embarked_C       7.895800       8.662500
# 7    2   1     [7.90, 8.66)       Embarked_Q       7.895800       8.662500
# 8    2   2     [7.90, 8.66)       Embarked_S       7.895800       8.662500
# 9    3   0    [8.66, 13.00)       Embarked_C       8.662500      13.000000
# 10   3   1    [8.66, 13.00)       Embarked_Q       8.662500      13.000000
# 11   3   2    [8.66, 13.00)       Embarked_S       8.662500      13.000000
# 12   4   0   [13.00, 16.70)       Embarked_C      13.000000      16.700000
# 13   4   1   [13.00, 16.70)       Embarked_Q      13.000000      16.700000
# 14   4   2   [13.00, 16.70)       Embarked_S      13.000000      16.700000
# 15   5   0   [16.70, 26.00)       Embarked_C      16.700000      26.000000
# 16   5   1   [16.70, 26.00)       Embarked_Q      16.700000      26.000000
# 17   5   2   [16.70, 26.00)       Embarked_S      16.700000      26.000000
# 18   6   0   [26.00, 35.11)       Embarked_C      26.000000      35.111111
# 19   6   1   [26.00, 35.11)       Embarked_Q      26.000000      35.111111
# 20   6   2   [26.00, 35.11)       Embarked_S      26.000000      35.111111
# 21   7   0   [35.11, 73.50)       Embarked_C      35.111111      73.500000
# 22   7   1   [35.11, 73.50)       Embarked_Q      35.111111      73.500000
# 23   7   2   [35.11, 73.50)       Embarked_S      35.111111      73.500000
# 24   8   0  [73.50, 512.33]       Embarked_C      73.500000     512.329200
# 25   8   1  [73.50, 512.33]       Embarked_Q      73.500000     512.329200
# 26   8   2  [73.50, 512.33]       Embarked_S      73.500000     512.329200
#
#     count  actual_prediction_q1  actual_prediction_q2  actual_prediction_q3
# 0    29.0              0.142362              0.148432              0.188724
# 1     7.0              0.072540              0.104625              0.351947
# 2    63.0              0.064330              0.084768              0.103244
# 3     0.0              0.000000              0.000000              0.000000
# 4    44.0              0.115931              0.380921              0.720176
# 5    42.0              0.098790              0.109310              0.130789
# 6     6.0              0.125047              0.149831              0.165808
# 7     3.0              0.373880              0.602145              0.658334
# 8   101.0              0.096117              0.116362              0.140325
# 9     6.0              0.166213              0.397281              0.661527
# 10    3.0              0.477166              0.882609              0.883496
# 11   82.0              0.113444              0.135180              0.471643
# 12   23.0              0.268804              0.570105              0.602508
# 13    8.0              0.157639              0.365452              0.674061
# 14   77.0              0.117689              0.131424              0.825269
# 15   11.0              0.409613              0.695065              0.846010
# 16    5.0              0.144498              0.151896              0.592054
# 17   55.0              0.144559              0.361095              0.805452
# 18   20.0              0.344796              0.401090              0.557573
# 19    5.0              0.096029              0.134049              0.152634
# 20  103.0              0.165503              0.294878              0.853509
# 21   24.0              0.335922              0.902478              0.954581
# 22    0.0              0.000000              0.000000              0.000000
# 23   72.0              0.149194              0.364329              0.846790
# 24   49.0              0.490621              0.940893              0.965071
# 25    2.0              0.464650              0.633510              0.802369
# 26   51.0              0.352949              0.901894              0.945245

# %% [markdown]
# #### (model: binary, feature_type: binary and numeric)

# %%
fig, axes, df = actual_plot_interact(model=titanic_model, 
                                X=titanic_data[titanic_features],
                                features=['Fare', 'Sex'], 
                                feature_names=['Fare', 'Sex'], figsize=(15, 8))
