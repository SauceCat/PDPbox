# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test binary classifier

# %%
test_titanic = joblib.load('../../pdpbox/datasets/test_titanic.pkl')

titanic_data = test_titanic['data']
titanic_features = test_titanic['features']
titanic_target = test_titanic['target']
titanic_model = test_titanic['xgb_model']

# %% [markdown]
# ## test target plot interact

# %%
from pdpbox.info_plots import target_plot_interact

# %% [markdown]
# #### (model: binary, feature_type: binary and onehot)

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                             features=['Sex', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                             feature_names=['Sex', 'Embarked'], 
                                             target=titanic_target)
_ = axes['value_ax'].set_xticklabels(['Female', 'Male'])

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                             features=['Sex', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                             feature_names=['Sex', 'Embarked'], 
                                             target=titanic_target, annotate=True)
_ = axes['value_ax'].set_xticklabels(['Female', 'Male'])

# %%
summary_df
# Out:
#    x1  x2 display_column_1 display_column_2  count  Survived
# 0   0   0            Sex_0       Embarked_C     73  0.876712
# 1   0   1            Sex_0       Embarked_Q     36  0.750000
# 2   0   2            Sex_0       Embarked_S    205  0.692683
# 3   1   0            Sex_1       Embarked_C     95  0.305263
# 4   1   1            Sex_1       Embarked_Q     41  0.073171
# 5   1   2            Sex_1       Embarked_S    441  0.174603

# %%
summary_df['count'].sum()
# Out:
# 891

# %% [markdown]
# #### (model: binary, feature_type: onehot and numeric)

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        figsize=(15, 10))

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        figsize=(15, 10), annotate=True)

# %%
summary_df.head()
# Out:
#    x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0   0   0     [0.00, 7.73)       Embarked_C       0.000000       7.732844
# 1   0   1     [0.00, 7.73)       Embarked_Q       0.000000       7.732844
# 2   0   2     [0.00, 7.73)       Embarked_S       0.000000       7.732844
# 3   1   0     [7.73, 7.90)       Embarked_C       7.732844       7.895800
# 4   1   1     [7.73, 7.90)       Embarked_Q       7.732844       7.895800
#
#    count  Survived
# 0   29.0  0.241379
# 1    7.0  0.000000
# 2   63.0  0.111111
# 3    0.0  0.000000
# 4   44.0  0.454545

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        endpoint=False)

# %%
# num_grid_points
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        num_grid_points=[15, None])

# %%
# grid_types
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        grid_types=['equal', 'equal'],
                                        figsize=(15, 8))

# %%
summary_df
# Out:
#     x1  x2  display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0    0   0     [0.00, 56.93)       Embarked_C       0.000000      56.925467
# 1    0   1     [0.00, 56.93)       Embarked_Q       0.000000      56.925467
# 2    0   2     [0.00, 56.93)       Embarked_S       0.000000      56.925467
# 3    1   0   [56.93, 113.85)       Embarked_C      56.925467     113.850933
# 4    1   1   [56.93, 113.85)       Embarked_Q      56.925467     113.850933
# 5    1   2   [56.93, 113.85)       Embarked_S      56.925467     113.850933
# 6    2   0  [113.85, 170.78)       Embarked_C     113.850933     170.776400
# 7    2   1  [113.85, 170.78)       Embarked_Q     113.850933     170.776400
# 8    2   2  [113.85, 170.78)       Embarked_S     113.850933     170.776400
# 9    3   0  [170.78, 227.70)       Embarked_C     170.776400     227.701867
# 10   3   1  [170.78, 227.70)       Embarked_Q     170.776400     227.701867
# 11   3   2  [170.78, 227.70)       Embarked_S     170.776400     227.701867
# 12   4   0  [227.70, 284.63)       Embarked_C     227.701867     284.627333
# 13   4   1  [227.70, 284.63)       Embarked_Q     227.701867     284.627333
# 14   4   2  [227.70, 284.63)       Embarked_S     227.701867     284.627333
# 15   5   0  [284.63, 341.55)       Embarked_C     284.627333     341.552800
# 16   5   1  [284.63, 341.55)       Embarked_Q     284.627333     341.552800
# 17   5   2  [284.63, 341.55)       Embarked_S     284.627333     341.552800
# 18   6   0  [341.55, 398.48)       Embarked_C     341.552800     398.478267
# 19   6   1  [341.55, 398.48)       Embarked_Q     341.552800     398.478267
# 20   6   2  [341.55, 398.48)       Embarked_S     341.552800     398.478267
# 21   7   0  [398.48, 455.40)       Embarked_C     398.478267     455.403733
# 22   7   1  [398.48, 455.40)       Embarked_Q     398.478267     455.403733
# 23   7   2  [398.48, 455.40)       Embarked_S     398.478267     455.403733
# 24   8   0  [455.40, 512.33]       Embarked_C     455.403733     512.329200
# 25   8   1  [455.40, 512.33]       Embarked_Q     455.403733     512.329200
# 26   8   2  [455.40, 512.33]       Embarked_S     455.403733     512.329200
#
#     count  Survived
# 0   108.0  0.425926
# 1    75.0  0.386667
# 2   579.0  0.307427
# 3    42.0  0.785714
# 4     2.0  0.500000
# 5    43.0  0.534884
# 6     6.0  0.833333
# 7     0.0  0.000000
# 8    16.0  0.812500
# 9     5.0  0.600000
# 10    0.0  0.000000
# 11    4.0  0.750000
# 12    4.0  0.750000
# 13    0.0  0.000000
# 14    4.0  0.500000
# 15    0.0  0.000000
# 16    0.0  0.000000
# 17    0.0  0.000000
# 18    0.0  0.000000
# 19    0.0  0.000000
# 20    0.0  0.000000
# 21    0.0  0.000000
# 22    0.0  0.000000
# 23    0.0  0.000000
# 24    3.0  1.000000
# 25    0.0  0.000000
# 26    0.0  0.000000

# %%
# percentile_ranges
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        percentile_ranges=[(5, 95), None])

# %%
# grid_ranges
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        grid_types = ['equal', 'equal'],
                                        grid_ranges=[(0, 100), None])

# %%
# cust_grid_points
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        cust_grid_points=[range(0, 100, 10), None])

# %%
# show_percentile, percentile_ranges
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        percentile_ranges=[(5, 95), None],
                                        show_percentile=True)

# %%
fig

# %%
axes
# Out:
# {'legend_ax': [<matplotlib.axes._subplots.AxesSubplot at 0xf94fb00>,
#   <matplotlib.axes._subplots.AxesSubplot at 0xfff7b70>],
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x103cc5c0>,
#  'value_ax': <matplotlib.axes._subplots.AxesSubplot at 0x10334470>}

# %%
summary_df.head()
# Out:
#    x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0   0   0     [7.22, 7.75)       Embarked_C          7.225         7.7500
# 1   0   1     [7.22, 7.75)       Embarked_Q          7.225         7.7500
# 2   0   2     [7.22, 7.75)       Embarked_S          7.225         7.7500
# 3   1   0     [7.75, 7.91)       Embarked_C          7.750         7.9104
# 4   1   1     [7.75, 7.91)       Embarked_Q          7.750         7.9104
#
#   percentile_column_1  percentile_lower_1  percentile_upper_1  count  Survived
# 0       [5.00, 15.00)                 5.0                15.0   27.0  0.259259
# 1       [5.00, 15.00)                 5.0                15.0   10.0  0.300000
# 2       [5.00, 15.00)                 5.0                15.0   26.0  0.153846
# 3      [15.00, 25.00)                15.0                25.0    5.0  0.200000
# 4      [15.00, 25.00)                15.0                25.0   37.0  0.459459

# %%
# show_percentile, percentile_ranges, show_outliers
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        percentile_ranges=[(5, 95), None],
                                        show_percentile=True,
                                        show_outliers=True)

# %%
# show_percentile, percentile_ranges, show_outliers, endpoint
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        percentile_ranges=[(5, 95), None],
                                        show_percentile=True,
                                        show_outliers=True,
                                        endpoint=False)

# %%
# grid_ranges, show_outliers
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        grid_types=['equal', 'equal'],
                                        grid_ranges=[(0, 100), None],
                                        show_outliers=True)

# %%
# grid_ranges, show_outliers, endpoint
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        grid_types=['equal', 'equal'],
                                        grid_ranges=[(0, 100), None],
                                        show_outliers=True,
                                        endpoint=False)

# %%
# cust_grid_points, show_outliers
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        cust_grid_points=[range(0, 100, 10), None],
                                        show_outliers=True)

# %%
# cust_grid_points, show_outliers, endpoint
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', ['Embarked_C', 'Embarked_Q', 'Embarked_S']], 
                                        feature_names=['Fare', 'Embarked'], 
                                        target=titanic_target, 
                                        cust_grid_points=[range(0, 100, 10), None],
                                        show_outliers=True,
                                        endpoint=False)

# %% [markdown]
# #### (model: binary, feature_type: binary and numeric)

# %%
fig, axes, summary_df = target_plot_interact(df=titanic_data, 
                                        features=['Fare', 'Sex'], 
                                        feature_names=['Fare', 'Sex'], 
                                        target=titanic_target, 
                                        show_percentile=True, 
                                        percentile_ranges=[(5, 95), None], 
                                        show_outliers=True)

# %%
axes
# Out:
# {'legend_ax': [<matplotlib.axes._subplots.AxesSubplot at 0x1212fa58>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1186cb00>],
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x11e7d160>,
#  'value_ax': <matplotlib.axes._subplots.AxesSubplot at 0x12008978>}

# %%
# plot_params
plot_params = {
    'font_family': 'Verdana',
    'title': 'Survival rate for different fares and gender',
    'subtitle': 'Average survival rate through different fare values and gender',
    'title_fontsize': 15,
    'subtitle_fontsize': 10,
    'cmap': 'Purples',
    'cmaps': ['Blues', 'Greens', 'Oranges', 'Reds', 'Purples', 'Greys'],
    'line_width': 1,
    'xticks_rotation': 30,
    'marker_size_min': 30,
    'marker_size_max': 800
}
_ = target_plot_interact(df=titanic_data, 
                         features=['Sex', 'Fare'], 
                         feature_names=['Sex', 'Fare'], 
                         target=titanic_target, 
                         figsize=(15, 15),
                         num_grid_points=[None, 20], 
                         plot_params=plot_params)
