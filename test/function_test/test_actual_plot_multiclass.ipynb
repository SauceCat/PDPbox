# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test multi-class

# %%
test_otto = joblib.load('../../pdpbox/datasets/test_otto.pkl')

otto_data = test_otto['data']
otto_features = test_otto['features']
otto_target = test_otto['target']
otto_model = test_otto['rf_model']

# %% [markdown]
# ## test actual_plot

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot

# %% [markdown]
# #### numeric feature

# %%
# one class
fig, axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       which_classes=[1])
# Out:
# ../../pdpbox\info_plots.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   info_df['actual_prediction_%d' % class_idx] = prediction[:, class_idx]

# %%
df
# Out:
#    x  display_column  value_lower  value_upper  count  actual_prediction_1_q1  \
# 0  0    [0.00, 1.00)          0.0          1.0  23930                     0.0
# 1  1    [1.00, 2.00)          1.0          2.0   9878                     0.0
# 2  2    [2.00, 3.00)          2.0          3.0   6689                     0.0
# 3  3    [3.00, 4.00)          3.0          4.0   4434                     0.0
# 4  4    [4.00, 7.00)          4.0          7.0   8985                     0.0
# 5  5  [7.00, 104.00]          7.0        104.0   7962                     0.0
#
#    actual_prediction_1_q2  actual_prediction_1_q3
# 0                    0.03                    0.26
# 1                    0.05                    0.88
# 2                    0.03                    0.89
# 3                    0.03                    0.88
# 4                    0.01                    0.74
# 5                    0.00                    0.04

# %%
fig

# %%
# multi-class
fig, axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       which_classes=[1, 2, 3])

# %%
df
# Out:
#    x  display_column  value_lower  value_upper  count  actual_prediction_1_q1  \
# 0  0    [0.00, 1.00)          0.0          1.0  23930                     0.0
# 1  1    [1.00, 2.00)          1.0          2.0   9878                     0.0
# 2  2    [2.00, 3.00)          2.0          3.0   6689                     0.0
# 3  3    [3.00, 4.00)          3.0          4.0   4434                     0.0
# 4  4    [4.00, 7.00)          4.0          7.0   8985                     0.0
# 5  5  [7.00, 104.00]          7.0        104.0   7962                     0.0
#
#    actual_prediction_1_q2  actual_prediction_1_q3  actual_prediction_2_q1  \
# 0                    0.03                    0.26                     0.0
# 1                    0.05                    0.88                     0.0
# 2                    0.03                    0.89                     0.0
# 3                    0.03                    0.88                     0.0
# 4                    0.01                    0.74                     0.0
# 5                    0.00                    0.04                     0.0
#
#    actual_prediction_2_q2  actual_prediction_2_q3  actual_prediction_3_q1  \
# 0                    0.02                    0.14                     0.0
# 1                    0.01                    0.06                     0.0
# 2                    0.01                    0.05                     0.0
# 3                    0.01                    0.06                     0.0
# 4                    0.00                    0.06                     0.0
# 5                    0.00                    0.02                     0.0
#
#    actual_prediction_3_q2  actual_prediction_3_q3
# 0                     0.0                    0.03
# 1                     0.0                    0.01
# 2                     0.0                    0.01
# 3                     0.0                    0.01
# 4                     0.0                    0.00
# 5                     0.0                    0.00

# %%
axes
# Out:
# {'bar_ax': [<matplotlib.axes._subplots.AxesSubplot at 0x26f14470>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x16b112e8>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x16d075f8>],
#  'box_ax': [<matplotlib.axes._subplots.AxesSubplot at 0x19766c88>,
#   <matplotlib.axes._subplots.AxesSubplot at 0xcd85be0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x16c770f0>],
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x2c2c7cf8>}

# %%
# multi-class, show_percentile
fig, axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       which_classes=[1, 2, 3], 
                       show_percentile=True)

# %%
axes
# Out:
# {'bar_ax': [<matplotlib.axes._subplots.AxesSubplot at 0x1b937f28>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2b9d0710>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x145b3978>],
#  'box_ax': [<matplotlib.axes._subplots.AxesSubplot at 0x1b8f04a8>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1739ccc0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1b313a58>],
#  'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x14a8c5f8>}

# %%
# multi-class, show_percentile, ncols
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       which_classes=[1, 2, 3], 
                       show_percentile=True, 
                       ncols=1, figsize=(15, 18))

# %%
# plot_params
plot_params = {
    'font_family': 'Verdana',
    'xticks_rotation': 0,
    'title': 'I am a title',
    'subtitle': 'I am a subtitle',
    'title_fontsize': 13,
    'subtitle_fontsize': 10,
    'box_line_width': 1.5,
    'box_color': '#3288bd',
    'box_width': 0.5,
    'bar_color': '#3288bd',
    'bar_width': 0.3,
    'box_colors_cmap': 'tab20b',
    #'box_colors': plt.get_cmap('tab20')(range(20))
}

axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       which_classes=[1, 2, 3], 
                       show_percentile=True, 
                       plot_params=plot_params)
