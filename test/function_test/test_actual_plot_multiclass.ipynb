# %%
import sys
sys.path.insert(0, '../../')

import joblib
import pandas as pd
import numpy as np

from pdpbox.info_plots import target_plot
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## test multi-class

# %%
test_otto = joblib.load('test_otto.pkl')

otto_data = test_otto['data']
otto_features = test_otto['features']
otto_target = test_otto['target']
otto_model = test_otto['rf_model']

# %% [markdown]
# ## test actual_plot

# %%
import sys
sys.path.insert(0, '../../')

from pdpbox.info_plots import actual_plot

# %% [markdown]
# #### numeric feature

# %%
# one class
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='percentile', 
                       percentile_range=None, 
                       grid_range=None, 
                       cust_grid_points=None, 
                       show_percentile=False, 
                       show_outliers=False, 
                       which_classes=[0], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=None)
# Out:
# ../../pdpbox\info_plots.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   info_df['actual_prediction_%d' % class_idx] = prediction[:, class_idx]

# %%
df
# Out:
#    x  display_column  count  actual_prediction_0
# 0  0    [0.00, 1.00)  23930             0.014004
# 1  1    [1.00, 2.00)   9878             0.019306
# 2  2    [2.00, 3.00)   6689             0.024602
# 3  3    [3.00, 4.00)   4434             0.036867
# 4  4    [4.00, 7.00)   8985             0.047415
# 5  5  [7.00, 104.00]   7962             0.083489

# %%
# multi class
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='percentile', 
                       percentile_range=None, 
                       grid_range=None, 
                       cust_grid_points=None, 
                       show_percentile=False, 
                       show_outliers=False, 
                       which_classes=[0, 1, 3, 4, 6], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=None)

# %%
df
# Out:
#    x  display_column  count  actual_prediction_0  actual_prediction_1  \
# 0  0    [0.00, 1.00)  23930             0.014004             0.237227
# 1  1    [1.00, 2.00)   9878             0.019306             0.345919
# 2  2    [2.00, 3.00)   6689             0.024602             0.337331
# 3  3    [3.00, 4.00)   4434             0.036867             0.334892
# 4  4    [4.00, 7.00)   8985             0.047415             0.264466
# 5  5  [7.00, 104.00]   7962             0.083489             0.119653
#
#    actual_prediction_3  actual_prediction_4  actual_prediction_6
# 0             0.077395             0.061649             0.039720
# 1             0.041437             0.043792             0.032379
# 2             0.028012             0.077695             0.037022
# 3             0.019229             0.038543             0.039729
# 4             0.013884             0.015233             0.046407
# 5             0.007516             0.001934             0.083536

# %%
# show_percentile, percentile_range, show_outliers
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='percentile', 
                       percentile_range=(5, 95), 
                       grid_range=None, 
                       cust_grid_points=None, 
                       show_percentile=True, 
                       show_outliers=True, 
                       which_classes=[0, 1, 3, 4, 6], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=None)

# %%
df
# Out:
#    x display_column percentile_column  count  actual_prediction_0  \
# 0  0   [0.00, 1.00)     [5.00, 45.00)  23930             0.014004
# 1  1   [1.00, 2.00)    [45.00, 65.00)   9878             0.019306
# 2  2   [2.00, 4.00)    [55.00, 75.00)  11123             0.029491
# 3  3   [4.00, 6.00)    [75.00, 85.00)   6632             0.044961
# 4  4  [6.00, 11.00]    [85.00, 95.00]   7571             0.066187
# 5  5        > 11.00           > 95.00   2744             0.106224
#
#    actual_prediction_1  actual_prediction_3  actual_prediction_4  \
# 0             0.237227             0.077395             0.061649
# 1             0.345919             0.041437             0.043792
# 2             0.336359             0.024510             0.062088
# 3             0.277750             0.015045             0.018219
# 4             0.172688             0.007813             0.003845
# 5             0.065397             0.009351             0.000849
#
#    actual_prediction_6
# ...

# %%
# grid_type, grid_range, show_outliers
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='equal', 
                       percentile_range=None, 
                       grid_range=(1, 10), 
                       cust_grid_points=None, 
                       show_percentile=False, 
                       show_outliers=True, 
                       which_classes=[0, 1, 3, 4, 6], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=None)

# %%
df
# Out:
#      x display_column  count  actual_prediction_0  actual_prediction_1  \
# 0    0         < 1.00  23930             0.014004             0.237227
# 1    1   [1.00, 2.00)   9878             0.019306             0.345919
# 2    2   [2.00, 3.00)   6689             0.024602             0.337331
# 3    3   [3.00, 4.00)   4434             0.036867             0.334892
# 4    4   [4.00, 5.00)   4116             0.039555             0.321448
# 5    5   [5.00, 6.00)   2516             0.053804             0.206264
# 6    6   [6.00, 7.00)   2353             0.054331             0.227025
# 7    7   [7.00, 8.00)   1649             0.069333             0.181850
# 8    8   [8.00, 9.00)   1358             0.059639             0.148844
# 9    9  [9.00, 10.00]   1713             0.076608             0.122032
# 10  10        > 10.00   3242             0.104315             0.074534
#
#     actual_prediction_3  actual_prediction_4  actual_prediction_6
# ...

# %%
# cust_grid_points and show_outliers
axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='percentile', 
                       percentile_range=None, 
                       grid_range=None, 
                       cust_grid_points=range(5), 
                       show_percentile=False, 
                       show_outliers=True, 
                       which_classes=[0, 1, 3, 4, 6], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=None)

# %%
# plot_params
plot_params = {
    'font_family': 'Verdana',
    'xticks_rotation': 0,
    'title': 'I am a title',
    'subtitle': 'I am a subtitle',
    'title_fontsize': 13,
    'subtitle_fontsize': 10,
    'box_line_width': 1.5,
    'box_line_color': '#66c2a5',
    'box_color': '#3288bd',
    'box_colors_cmap': 'tab10',
    'box_width': 0.5,
    'bar_color': '#3288bd',
    'bar_width': 0.3
}

axes, df = actual_plot(model=otto_model, 
                       X=otto_data[otto_features], 
                       feature='feat_67', 
                       feature_name='feat_67', 
                       num_grid_points=10, 
                       grid_type='percentile', 
                       percentile_range=None, 
                       grid_range=None, 
                       cust_grid_points=range(5), 
                       show_percentile=False, 
                       show_outliers=True, 
                       which_classes=[0, 1, 3, 4, 6], 
                       predict_kwds={}, 
                       ncols=2, 
                       figsize=None, 
                       plot_params=plot_params)
